# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model
df = pd.read_csv("homeprices.csv")
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
type(df.price)
# Out:
# pandas.core.series.Series

# %%
df = pd.read_csv("homeprices.csv")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
type(df.price)
# Out:
# pandas.core.series.Series

# %%
# %matplotlib inline
plt.xlabel('area(sq ft.)')
plt.ylabel('price(US$)')
plt.scatter(df.area,df.price,color='red',marker='o')
plt.plot(df.area, reg.predict(df[['area']]),color='blue')

# %%
reg.predict([[5000]])
# Out:
# /Users/sayandas/jupyter_notebook/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
d = pd.read_csv("areas.csv")

# %%
predicted_df = reg.predict(d)
predicted_df
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d['prices'] = predicted_df

# %%
d.to_csv("prediction.csv",index=False)
